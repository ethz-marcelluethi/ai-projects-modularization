# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns
from src import download_penguins_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 from load_data import download_penguins_data
#
# ModuleNotFoundError: No module named 'load_data'

# %%
# Download and load the penguins dataset
df = download_penguins_data()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Download and load the penguins dataset
# ----> 2 df = download_penguins_data()
#       3 df
#
# NameError: name 'download_penguins_data' is not defined

# %%
sns.pairplot(df, hue="species")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.pairplot(df, hue="species")
#
# NameError: name 'df' is not defined
